# %% [markdown]
# <a href="https://colab.research.google.com/github/frontez/subtitles/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22WhisperX_Word_Level_transcript_time_stamping%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Check GPU availability

# %%
# !nvidia-smi
# Out:
# Mon Jan 13 20:33:14 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # Install WhisperX

# %%
! pip install git+https://github.com/m-bain/whisperx.git
# Out:
# ...
#   Cloning https://github.com/m-bain/whisperx.git to /tmp/pip-req-build-960klfxl
#   Running command git clone --filter=blob:none --quiet https://github.com/m-bain/whisperx.git /tmp/pip-req-build-960klfxl
#   Resolved https://github.com/m-bain/whisperx.git to commit 1027367b797a4ab0c8516211517cbf4f123c3488
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# # Install Whisper

# %%
! pip install git+https://github.com/openai/whisper.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-kp6oxma_
#   Running command git clone -q https://github.com/openai/whisper.git /tmp/pip-req-build-kp6oxma_
# ...
#   Created wheel for whisper: filename=whisper-1.0-py3-none-any.whl size=1175324 sha256=fb5d8994e94012f44ba956538d9a02a2355e83702de6a49cf91402c1ea950746
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ygruw6ow/wheels/a7/70/18/b7693c07b1d18b3dafb328f5d0496aa0d41a9c09ef332fd8e6
# Successfully built whisper
# ...

# %% [markdown]
# # Upload Input Audio / Video File

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e139528e-9e60-49ec-a2b9-a6983096c03a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e139528e-9e60-49ec-a2b9-a6983096c03a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Get Ass Subtitle File Saved using WhisperX

# %%
# !whisperx "Jimmy Kimmel Asks Keanu Reeves Random Questions.mp4" --model medium.en --output_dir . --align_model WAV2VEC2_ASR_LARGE_LV60K_960H
# Out:
# 2025-01-13 20:39:33.701314: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-13 20:39:33.723768: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-13 20:39:33.730035: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-13 20:39:33.744503: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# prompt: execute python file from the working directory called ass_generator.py

# !python ass_generator4.py

# %% [markdown]
# # Burn the Ass Subtitle file to the Video

# %%
# !ffmpeg -i "Jimmy Kimmel Asks Keanu Reeves Random Questions.mp4" -vf "ass=output.ass" new_video_out.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
